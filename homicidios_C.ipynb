# %% [markdown]
# # Data Lesiones Homicidios

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/acubillosde/Analitica_Sabana_Completo/main/init.py
import init; init.init(force_download=False);

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
from unidecode import unidecode

# %%
files_1 = ['./local/data/homicidios/' + str(i) + '.xlsx' for i in range(2010, 2013)]
files_2 = ['./local/data/homicidios/' + str(i) + '.xls' for i in range(2013, 2020)]
files = files_1+files_2
print(files)
# Out:
# ['./local/data/homicidios/2010.xlsx', './local/data/homicidios/2011.xlsx', './local/data/homicidios/2012.xlsx', './local/data/homicidios/2013.xls', './local/data/homicidios/2014.xls', './local/data/homicidios/2015.xls', './local/data/homicidios/2016.xls', './local/data/homicidios/2017.xls', './local/data/homicidios/2018.xls', './local/data/homicidios/2019.xls']

# %%
files
# Out:
# ['./local/data/homicidios/2010.xlsx',
#  './local/data/homicidios/2011.xlsx',
#  './local/data/homicidios/2012.xlsx',
#  './local/data/homicidios/2013.xls',
#  './local/data/homicidios/2014.xls',
#  './local/data/homicidios/2015.xls',
#  './local/data/homicidios/2016.xls',
#  './local/data/homicidios/2017.xls',
#  './local/data/homicidios/2018.xls',
#  './local/data/homicidios/2019.xls']

# %%
all_dfs = []

for file in files:
    temp = pd.read_excel(file)
    
    # Eliminar acentos en el nombre de las columnas
    temp.columns = [unidecode(str(col)) for col in temp.columns]

    # Reemplazar espacios por _
    temp.columns = temp.columns.str.replace(' ', '_')
    
    # Strip
    temp.columns = temp.columns.str.strip()

    # Convierte todas las letras en minúsculas
    temp.columns = temp.columns.str.lower()

    # Reemplazar NaN, None
    temp.replace('-', np.nan, inplace=True)

    # Set axis name
    temp.rename_axis('id', inplace=True)
    
    all_dfs.append(temp)

# %%
all_dfs
# Out:
# [                                                   fecha departamento  \
#  id
#  0                                    2010-01-01 00:00:00    ANTIOQUIA
#  1                                    2010-01-01 00:00:00    ANTIOQUIA
#  2                                    2010-01-01 00:00:00    ANTIOQUIA
#  3                                    2010-01-01 00:00:00    ANTIOQUIA
#  4                                    2010-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  14949                                2010-12-31 00:00:00        VALLE
#  14950                                              TOTAL          NaN
#  14951  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  14952                                                NaN          NaN
#  14953  **PARA ANÁLISIS CRIMINOLÓGICOS SE DEBEN INCLUI...          NaN
#
#             municipio      dia      hora                     barrio    zona  \
#  id
#  0              AMAGÁ  Viernes  14:00:00       MALABRIGO PARTE ALTA   RURAL
#  1         COPACABANA  Viernes  08:30:00            LA MISERICORDIA  URBANA
#  2      MEDELLÍN (CT)  Viernes  02:00:00           LAS GRANJAS  C-3  URBANA
#  3      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
#  4      MEDELLÍN (CT)  Viernes  11:10:00  ALEJANDRO ECHAVARRIA  C-9  URBANA
#  ...              ...      ...       ...                        ...     ...
#  14949        PRADERA  Viernes  00:20:00                   MARSELLA  URBANA
#  14950            NaN      NaN       NaN                        NaN     NaN
#  14951            NaN      NaN       NaN                        NaN     NaN
#  14952            NaN      NaN       NaN                        NaN     NaN
#  14953            NaN      NaN       NaN                        NaN     NaN
#
#                                clase_sitio  arma_empleada movil_agresor  \
#  id
#  0                      FINCAS Y SIMILARES    ARMA BLANCA         A PIE
#  1      FRENTE A RESIDENCIAS - VIA PUBLICA  ARMA DE FUEGO         A PIE
#  2                           VIAS PUBLICAS  ARMA DE FUEGO         A PIE
#  3                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
#  4                   ESCENARIOS DEPORTIVOS  ARMA DE FUEGO         A PIE
#  ...                                   ...            ...           ...
#  14949                       VIAS PUBLICAS  ARMA DE FUEGO  NO REPORTADO
#  14950                                 NaN            NaN           NaN
#  14951                                 NaN            NaN           NaN
#  14952                                 NaN            NaN           NaN
#  14953                                 NaN            NaN           NaN
#
#        movil_victima edad       sexo estado_civil pais_nace  \
#  id
#  0             A PIE   49  MASCULINO       CASADO  COLOMBIA
#  1             A PIE   32  MASCULINO  UNION LIBRE  COLOMBIA
#  2             A PIE   33  MASCULINO  UNION LIBRE  COLOMBIA
#  3             A PIE   23  MASCULINO      SOLTERO  COLOMBIA
#  4             A PIE   23  MASCULINO      SOLTERO  COLOMBIA
#  ...             ...  ...        ...          ...       ...
#  14949         A PIE   20  MASCULINO      SOLTERO  COLOMBIA
#  14950           NaN  NaN        NaN          NaN       NaN
#  14951           NaN  NaN        NaN          NaN       NaN
#  14952           NaN  NaN        NaN          NaN       NaN
#  14953           NaN  NaN        NaN          NaN       NaN
#
#              clase_empleado   profesiones escolaridad  codigo_dane     2010
#  id
#  0      EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA    5030000.0      1.0
#  1            INDEPENDIENTE  NO REPORTADO  SECUNDARIA    5212000.0      1.0
#  2              DESEMPLEADO  NO REPORTADO  SECUNDARIA    5001000.0      1.0
#  3               ESTUDIANTE  NO REPORTADO  SECUNDARIA    5001000.0      1.0
#  4      EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA    5001000.0      1.0
#  ...                    ...           ...         ...          ...      ...
#  14949  EMPLEADO PARTICULAR  NO REPORTADA  SECUNDARIA   76563000.0      1.0
#  14950                  NaN           NaN         NaN          NaN  15013.0
#  14951                  NaN           NaN         NaN          NaN      NaN
#  14952                  NaN           NaN         NaN          NaN      NaN
#  14953                  NaN           NaN         NaN          NaN      NaN
#
#  [14954 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2011-01-01 00:00:00    ANTIOQUIA
#  1                                    2011-01-01 00:00:00    ANTIOQUIA
#  2                                    2011-01-01 00:00:00    ANTIOQUIA
#  3                                    2011-01-01 00:00:00    ANTIOQUIA
#  4                                    2011-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  15735                                2011-12-31 00:00:00        VALLE
#  15736                                              TOTAL          NaN
#  15737  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  15738                                                NaN          NaN
#  15739  **PARA ANÁLISIS CRIMINOLÓGICOS SE DEBEN INCLUI...          NaN
#
#           municipio     dia      hora                barrio    zona  \
#  id
#  0            AMAGÁ  Sábado  05:56:00          NO REPORTADO  URBANA
#  1           ITAGUI  Sábado  06:00:00      VDA. EL PEDREGAL   RURAL
#  2           ITAGUI  Sábado  14:00:00           SAN GABRIEL  URBANA
#  3           ITAGUI  Sábado  14:00:00           SAN GABRIEL  URBANA
#  4      LA ESTRELLA  Sábado  11:45:00            SAN ANDRES  URBANA
#  ...            ...     ...       ...                   ...     ...
#  15735      SEVILLA  Sábado  14:00:00  VEREDA LA CRISTALINA   RURAL
#  15736          NaN     NaN       NaN                   NaN     NaN
#  15737          NaN     NaN       NaN                   NaN     NaN
#  15738          NaN     NaN       NaN                   NaN     NaN
#  15739          NaN     NaN       NaN                   NaN     NaN
#
#           clase_sitio  arma_empleada movil_agresor movil_victima edad  \
#  id
#  0      VIAS PUBLICAS    ARMA BLANCA         A PIE         A PIE   28
#  1      VIAS PUBLICAS  ARMA DE FUEGO         A PIE         A PIE   54
#  2      VIAS PUBLICAS  ARMA DE FUEGO         A PIE         A PIE   23
#  3      VIAS PUBLICAS  ARMA DE FUEGO         A PIE         A PIE   33
#  4      VIAS PUBLICAS  ARMA DE FUEGO         A PIE         A PIE   25
#  ...              ...            ...           ...           ...  ...
#  15735  VIAS PUBLICAS  ARMA DE FUEGO         A PIE         A PIE   31
#  15736            NaN            NaN           NaN           NaN  NaN
#  15737            NaN            NaN           NaN           NaN  NaN
#  15738            NaN            NaN           NaN           NaN  NaN
#  15739            NaN            NaN           NaN           NaN  NaN
#
#              sexo estado_civil pais_nace       clase_empleado   profesiones  \
#  id
#  0      MASCULINO  UNION LIBRE  COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO
#  1      MASCULINO  UNION LIBRE  COLOMBIA        INDEPENDIENTE  NO REPORTADO
#  2       FEMENINO      SOLTERO  COLOMBIA  EMPLEADO PARTICULAR  NO REPORTADO
#  3      MASCULINO      SOLTERO  COLOMBIA        INDEPENDIENTE  NO REPORTADO
#  4      MASCULINO      SOLTERO  COLOMBIA        INDEPENDIENTE  NO REPORTADO
#  ...          ...          ...       ...                  ...           ...
#  15735  MASCULINO      SOLTERO  COLOMBIA          DESEMPLEADO  NO REPORTADA
#  15736        NaN          NaN       NaN                  NaN           NaN
#  15737        NaN          NaN       NaN                  NaN           NaN
#  15738        NaN          NaN       NaN                  NaN           NaN
#  15739        NaN          NaN       NaN                  NaN           NaN
#
#        escolaridad  codigo_dane     2011
#  id
#  0        PRIMARIA    5030000.0      1.0
#  1      SECUNDARIA    5360000.0      1.0
#  2      SECUNDARIA    5360000.0      1.0
#  3        PRIMARIA    5360000.0      1.0
#  4      SECUNDARIA    5380000.0      1.0
#  ...           ...          ...      ...
#  15735  SECUNDARIA   76736000.0      1.0
#  15736         NaN          NaN  15803.0
#  15737         NaN          NaN      NaN
#  15738         NaN          NaN      NaN
#  15739         NaN          NaN      NaN
#
#  [15740 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2012-01-01 00:00:00    ANTIOQUIA
#  1                                    2012-01-01 00:00:00    ANTIOQUIA
#  2                                    2012-01-01 00:00:00    ANTIOQUIA
#  3                                    2012-01-01 00:00:00    ANTIOQUIA
#  4                                    2012-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  15967                                2012-12-31 00:00:00        VALLE
#  15968                                              TOTAL          NaN
#  15969  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  15970                                                NaN          NaN
#  15971  **PARA ANÁLISIS CRIMINOLÓGICOS SE DEBEN INCLUI...          NaN
#
#              municipio      dia      hora            barrio    zona  \
#  id
#  0               ANDES  Domingo  09:00:00               NaN   RURAL
#  1             CÁCERES  Domingo  06:30:00        CAMPANARIO   RURAL
#  2      CIUDAD BOLÍVAR  Domingo  07:00:00  PARQUE PRINCIPAL  URBANA
#  3       MEDELLÍN (CT)  Domingo  03:30:00  LAS GRANJAS  C-3  URBANA
#  4       MEDELLÍN (CT)  Domingo  04:38:00  LAS GRANJAS  C-3  URBANA
#  ...               ...      ...       ...               ...     ...
#  15967           TULUÁ    Lunes  16:45:00           Popular  URBANA
#  15968             NaN      NaN       NaN               NaN     NaN
#  15969             NaN      NaN       NaN               NaN     NaN
#  15970             NaN      NaN       NaN               NaN     NaN
#  15971             NaN      NaN       NaN               NaN     NaN
#
#                 clase_sitio  arma_empleada          movil_agresor  \
#  id
#  0       FINCAS Y SIMILARES    ARMA BLANCA                  A PIE
#  1       FINCAS Y SIMILARES    ARMA BLANCA                  A PIE
#  2      CASAS DE HABITACION    ARMA BLANCA                  A PIE
#  3            VIAS PUBLICAS    ARMA BLANCA                  A PIE
#  4            VIAS PUBLICAS  ARMA DE FUEGO                  A PIE
#  ...                    ...            ...                    ...
#  15967     CANCHA DE FUTBOL  ARMA DE FUEGO  CONDUCTOR MOTOCICLETA
#  15968                  NaN            NaN                    NaN
#  15969                  NaN            NaN                    NaN
#  15970                  NaN            NaN                    NaN
#  15971                  NaN            NaN                    NaN
#
#        movil_victima edad       sexo estado_civil pais_nace  \
#  id
#  0             A PIE   23  MASCULINO      SOLTERO  COLOMBIA
#  1             A PIE   31  MASCULINO  UNION LIBRE  COLOMBIA
#  2             A PIE   47  MASCULINO  UNION LIBRE  COLOMBIA
#  3             A PIE   37  MASCULINO      SOLTERO  COLOMBIA
#  4             A PIE   28  MASCULINO      SOLTERO  COLOMBIA
#  ...             ...  ...        ...          ...       ...
#  15967         A PIE   29  MASCULINO  UNION LIBRE  COLOMBIA
#  15968           NaN  NaN        NaN          NaN       NaN
#  15969           NaN  NaN        NaN          NaN       NaN
#  15970           NaN  NaN        NaN          NaN       NaN
#  15971           NaN  NaN        NaN          NaN       NaN
#
#              clase_empleado   profesiones escolaridad  codigo_dane     2012
#  id
#  0               AGRICULTOR  NO REPORTADO    PRIMARIA    5034000.0      1.0
#  1      EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA    5120000.0      1.0
#  2      EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA    5101000.0      1.0
#  3            INDEPENDIENTE  NO REPORTADO  SECUNDARIA    5001000.0      1.0
#  4            INDEPENDIENTE  NO REPORTADO  SECUNDARIA    5001000.0      1.0
#  ...                    ...           ...         ...          ...      ...
#  15967  EMPLEADO PARTICULAR  NO REPORTADA    PRIMARIA   76834000.0      1.0
#  15968                  NaN           NaN         NaN          NaN  16032.0
#  15969                  NaN           NaN         NaN          NaN      NaN
#  15970                  NaN           NaN         NaN          NaN      NaN
#  15971                  NaN           NaN         NaN          NaN      NaN
#
#  [15972 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2013-01-01 00:00:00    ANTIOQUIA
#  1                                    2013-01-01 00:00:00    ANTIOQUIA
#  2                                    2013-01-01 00:00:00    ANTIOQUIA
#  3                                    2013-01-01 00:00:00    ANTIOQUIA
#  4                                    2013-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  14920                                2013-12-31 00:00:00        VALLE
#  14921                                              TOTAL          NaN
#  14922  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  14923            Elaboró: SI Juan Gabriel Moreno Moreno.          NaN
#  14924     Revisó: SI. Diana Patricia Hernández Hernández          NaN
#
#                   municipio     dia      hora           barrio    zona  \
#  id
#  0                    ANDES  Martes  09:30:00  QUEBRADA ARRIBA   RURAL
#  1                  BETULIA  Martes  01:55:00              NaN   RURAL
#  2                 BURITICÁ  Martes  15:30:00         LA RONDA  URBANA
#  3                 EL BAGRE  Martes  16:00:00         SAN JOSE  URBANA
#  4                 EL BAGRE  Martes  00:05:00      LA FLORESTA  URBANA
#  ...                    ...     ...       ...              ...     ...
#  14920  GUADALAJARA DE BUGA  Martes  00:30:00      DIVINO NIÑO  URBANA
#  14921                  NaN     NaN       NaN              NaN     NaN
#  14922                  NaN     NaN       NaN              NaN     NaN
#  14923                  NaN     NaN       NaN              NaN     NaN
#  14924                  NaN     NaN       NaN              NaN     NaN
#
#             clase_de_sitio                arma_empleada movil_agresor  \
#  id
#  0      FINCAS Y SIMILARES                ARMA DE FUEGO         A PIE
#  1                 PARQUES  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  2           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  3                ESTADERO                ARMA DE FUEGO         A PIE
#  4       BOMBA DE GASOLINA              GRANADA DE MANO         A PIE
#  ...                   ...                          ...           ...
#  14920       VIAS PUBLICAS                ARMA DE FUEGO         A PIE
#  14921                 NaN                          NaN           NaN
#  14922                 NaN                          NaN           NaN
#  14923                 NaN                          NaN           NaN
#  14924                 NaN                          NaN           NaN
#
#        movil_victima  edad       sexo estado_civil pais_de_nacimiento  \
#  id
#  0             A PIE  34.0  MASCULINO  UNION LIBRE           COLOMBIA
#  1             A PIE  21.0  MASCULINO      SOLTERO           COLOMBIA
#  2             A PIE  43.0  MASCULINO       CASADO           COLOMBIA
#  3             A PIE  26.0  MASCULINO      SOLTERO           COLOMBIA
#  4             A PIE  51.0  MASCULINO       CASADO           COLOMBIA
#  ...             ...   ...        ...          ...                ...
#  14920         A PIE  30.0  MASCULINO  UNION LIBRE           COLOMBIA
#  14921           NaN   NaN        NaN          NaN                NaN
#  14922           NaN   NaN        NaN          NaN                NaN
#  14923           NaN   NaN        NaN          NaN                NaN
#  14924           NaN   NaN        NaN          NaN                NaN
#
#           clase_de_empleado     profesion escolaridad  codigo_dane  cantidad
#  id
#  0      EMPLEADO PARTICULAR           NaN    PRIMARIA    5034000.0       1.0
#  1              DESEMPLEADO           NaN  ANALFABETA    5093000.0       1.0
#  2      EMPLEADO PARTICULAR           NaN  ANALFABETA    5113000.0       1.0
#  3      EMPLEADO PARTICULAR           NaN    PRIMARIA    5250000.0       1.0
#  4      EMPLEADO PARTICULAR           NaN  SECUNDARIA    5250000.0       1.0
#  ...                    ...           ...         ...          ...       ...
#  14920  EMPLEADO PARTICULAR  NO REPORTADA    PRIMARIA   76111000.0       1.0
#  14921                  NaN           NaN         NaN          NaN   14970.0
#  14922                  NaN           NaN         NaN          NaN       NaN
#  14923                  NaN           NaN         NaN          NaN       NaN
#  14924                  NaN           NaN         NaN          NaN       NaN
#
#  [14925 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2014-01-01 00:00:00    ANTIOQUIA
#  1                                    2014-01-01 00:00:00    ANTIOQUIA
#  2                                    2014-01-01 00:00:00    ANTIOQUIA
#  3                                    2014-01-01 00:00:00    ANTIOQUIA
#  4                                    2014-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12929                                2014-12-31 00:00:00        VALLE
#  12930                                              TOTAL          NaN
#  12931  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  12932            Elaboró: SI Juan Gabriel Moreno Moreno.          NaN
#  12933     Revisó: SI. Diana Patricia Hernández Hernández          NaN
#
#        municipio        dia      hora        barrio    zona  \
#  id
#  0         ANORÍ  Miércoles  09:00:00     EL ZAFIRO   RURAL
#  1       BARBOSA  Miércoles  04:00:00    30 DE MAYO  URBANA
#  2         BELLO  Miércoles  15:15:00    MARUCHENGA  URBANA
#  3         BELLO  Miércoles  09:01:00   LAS GRANJAS  URBANA
#  4      BURITICÁ  Miércoles  07:00:00    LOS MANGOS   RURAL
#  ...         ...        ...       ...           ...     ...
#  12929   PRADERA  Miércoles  14:30:00  LA ESPERANZA  URBANA
#  12930       NaN        NaN       NaN           NaN     NaN
#  12931       NaN        NaN       NaN           NaN     NaN
#  12932       NaN        NaN       NaN           NaN     NaN
#  12933       NaN        NaN       NaN           NaN     NaN
#
#             clase_de_sitio                arma_empleada          movil_agresor  \
#  id
#  0      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE                  A PIE
#  1           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE                  A PIE
#  2           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE                  A PIE
#  3           VIAS PUBLICAS                 CONTUNDENTES                    NaN
#  4      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE                  A PIE
#  ...                   ...                          ...                    ...
#  12929       VIAS PUBLICAS                ARMA DE FUEGO  CONDUCTOR MOTOCICLETA
#  12930                 NaN                          NaN                    NaN
#  12931                 NaN                          NaN                    NaN
#  12932                 NaN                          NaN                    NaN
#  12933                 NaN                          NaN                    NaN
#
#        movil_victima  edad       sexo estado_civil pais_de_nacimiento  \
#  id
#  0             A PIE  37.0  MASCULINO  UNION LIBRE           COLOMBIA
#  1             A PIE  41.0  MASCULINO  UNION LIBRE           COLOMBIA
#  2             A PIE  34.0  MASCULINO      SOLTERO           COLOMBIA
#  3             A PIE  37.0  MASCULINO  UNION LIBRE                NaN
#  4             A PIE  51.0  MASCULINO       CASADO           COLOMBIA
#  ...             ...   ...        ...          ...                ...
#  12929         A PIE  28.0  MASCULINO      SOLTERO           COLOMBIA
#  12930           NaN   NaN        NaN          NaN                NaN
#  12931           NaN   NaN        NaN          NaN                NaN
#  12932           NaN   NaN        NaN          NaN                NaN
#  12933           NaN   NaN        NaN          NaN                NaN
#
#           clase_de_empleado profesion escolaridad  codigo_dane  cantidad
#  id
#  0      EMPLEADO PARTICULAR       NaN    PRIMARIA    5040000.0       1.0
#  1      EMPLEADO PARTICULAR       NaN  SECUNDARIA    5079000.0       1.0
#  2      EMPLEADO PARTICULAR       NaN    PRIMARIA    5088000.0       1.0
#  3              DESEMPLEADO       NaN  SECUNDARIA    5088000.0       1.0
#  4      EMPLEADO PARTICULAR       NaN    PRIMARIA    5113000.0       1.0
#  ...                    ...       ...         ...          ...       ...
#  12929  EMPLEADO PARTICULAR       NaN  SECUNDARIA   76563000.0       1.0
#  12930                  NaN       NaN         NaN          NaN   12957.0
#  12931                  NaN       NaN         NaN          NaN       NaN
#  12932                  NaN       NaN         NaN          NaN       NaN
#  12933                  NaN       NaN         NaN          NaN       NaN
#
#  [12934 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2015-01-01 00:00:00    ANTIOQUIA
#  1                                    2015-01-01 00:00:00    ANTIOQUIA
#  2                                    2015-01-01 00:00:00    ANTIOQUIA
#  3                                    2015-01-01 00:00:00    ANTIOQUIA
#  4                                    2015-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12439                                2015-12-31 00:00:00      VICHADA
#  12440                                              TOTAL          NaN
#  12441  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  12442            Elaboró: SI Juan Gabriel Moreno Moreno.          NaN
#  12443     Revisó: SI. Diana Patricia Hernández Hernández          NaN
#
#             municipio     dia      hora          barrio    zona  \
#  id
#  0              AMAGÁ  Jueves  06:00:00       EL VOLCAN   RURAL
#  1            BARBOSA  Jueves  09:00:00  VDA. MATASANOS   RURAL
#  2           EL BAGRE  Jueves  19:00:00   PUERTO CLAVER   RURAL
#  3             JARDÍN  Jueves  11:20:00      CRISTIANIA   RURAL
#  4      MEDELLÍN (CT)  Jueves  15:00:00   PICACHITO C-6  URBANA
#  ...              ...     ...       ...             ...     ...
#  12439       CUMARIBO  Jueves  22:55:00       EL CENTRO  URBANA
#  12440            NaN     NaN       NaN             NaN     NaN
#  12441            NaN     NaN       NaN             NaN     NaN
#  12442            NaN     NaN       NaN             NaN     NaN
#  12443            NaN     NaN       NaN             NaN     NaN
#
#                             clase_de_sitio                arma_empleada  \
#  id
#  0                                  TIENDA  ARMA BLANCA / CORTOPUNZANTE
#  1                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#  2                      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE
#  3                      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE
#  4      FRENTE A RESIDENCIAS - VIA PUBLICA                 CONTUNDENTES
#  ...                                   ...                          ...
#  12439                          HOSPITALES  ARMA BLANCA / CORTOPUNZANTE
#  12440                                 NaN                          NaN
#  12441                                 NaN                          NaN
#  12442                                 NaN                          NaN
#  12443                                 NaN                          NaN
#
#        movil_agresor movil_victima  edad       sexo estado_civil  \
#  id
#  0             A PIE         A PIE  44.0  MASCULINO       CASADO
#  1             A PIE         A PIE  30.0  MASCULINO      SOLTERO
#  2             A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
#  3             A PIE         A PIE  40.0  MASCULINO       CASADO
#  4             A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#  ...             ...           ...   ...        ...          ...
#  12439         A PIE         A PIE  23.0  MASCULINO      SOLTERO
#  12440           NaN           NaN   NaN        NaN          NaN
#  12441           NaN           NaN   NaN        NaN          NaN
#  12442           NaN           NaN   NaN        NaN          NaN
#  12443           NaN           NaN   NaN        NaN          NaN
#
#        pais_de_nacimiento clase_de_empleado profesion escolaridad  codigo_dane  \
#  id
#  0               COLOMBIA     INDEPENDIENTE       NaN    PRIMARIA    5030000.0
#  1                    NaN       DESEMPLEADO       NaN  SECUNDARIA    5079000.0
#  2               COLOMBIA        AGRICULTOR       NaN    PRIMARIA    5250000.0
#  3               COLOMBIA        AGRICULTOR       NaN    PRIMARIA    5364000.0
#  4               COLOMBIA       DESEMPLEADO       NaN    PRIMARIA    5001000.0
#  ...                  ...               ...       ...         ...          ...
#  12439           COLOMBIA     INDEPENDIENTE       NaN  SECUNDARIA   99773000.0
#  12440                NaN               NaN       NaN         NaN          NaN
#  12441                NaN               NaN       NaN         NaN          NaN
#  12442                NaN               NaN       NaN         NaN          NaN
#  12443                NaN               NaN       NaN         NaN          NaN
#
#         cantidad
#  id
#  0           1.0
#  1           1.0
#  2           1.0
#  3           1.0
#  4           1.0
#  ...         ...
#  12439       1.0
#  12440   12460.0
#  12441       NaN
#  12442       NaN
#  12443       NaN
#
#  [12444 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2016-01-01 00:00:00     AMAZONAS
#  1                                    2016-01-01 00:00:00    ANTIOQUIA
#  2                                    2016-01-01 00:00:00    ANTIOQUIA
#  3                                    2016-01-01 00:00:00    ANTIOQUIA
#  4                                    2016-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12139                                2016-12-31 00:00:00        VALLE
#  12140                                              TOTAL          NaN
#  12141  FUENTE: GRUPO INFORMACIÓN DE CRIMINALIDAD (GIC...          NaN
#  12142            Elaboró: SI Juan Gabriel Moreno Moreno.          NaN
#  12143     Revisó: SI. Diana Patricia Hernández Hernández          NaN
#
#             municipio      dia      hora                barrio    zona  \
#  id
#  0       LETICIA (CT)  Viernes  09:10:00                 UNION  URBANA
#  1              ANDES  Viernes  03:04:00       QUEBRADA ARRIBA   RURAL
#  2      MEDELLÍN (CT)  Viernes  07:30:00       MANRIQUE 2  C-3  URBANA
#  3      MEDELLÍN (CT)  Viernes  19:40:00         ARANJUEZ  C-4  URBANA
#  4      MEDELLÍN (CT)  Viernes  11:20:00  CERRO EL VOLADOR C-7  URBANA
#  ...              ...      ...       ...                   ...     ...
#  12139       TRUJILLO   Sábado  23:30:00    CTO. DOS QUEBARDAS   RURAL
#  12140            NaN      NaN       NaN                   NaN     NaN
#  12141            NaN      NaN       NaN                   NaN     NaN
#  12142            NaN      NaN       NaN                   NaN     NaN
#  12143            NaN      NaN       NaN                   NaN     NaN
#
#              clase_de_sitio                arma_empleada movil_agresor  \
#  id
#  0      CASAS DE HABITACION  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  1       FINCAS Y SIMILARES                ARMA DE FUEGO         A PIE
#  2            VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  3            VIAS PUBLICAS                ARMA DE FUEGO         A PIE
#  4            VIAS PUBLICAS           CUERDA/SOGA/CADENA         A PIE
#  ...                    ...                          ...           ...
#  12139        VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  12140                  NaN                          NaN           NaN
#  12141                  NaN                          NaN           NaN
#  12142                  NaN                          NaN           NaN
#  12143                  NaN                          NaN           NaN
#
#        movil_victima  edad       sexo estado_civil pais_de_nacimiento  \
#  id
#  0             A PIE  47.0  MASCULINO  UNION LIBRE           COLOMBIA
#  1             A PIE  42.0  MASCULINO      SOLTERO           COLOMBIA
#  2             A PIE  51.0  MASCULINO      SOLTERO           COLOMBIA
#  3             A PIE  22.0  MASCULINO      SOLTERO           COLOMBIA
#  4             A PIE  62.0  MASCULINO      SOLTERO           COLOMBIA
#  ...             ...   ...        ...          ...                ...
#  12139         A PIE  59.0  MASCULINO  UNION LIBRE           COLOMBIA
#  12140           NaN   NaN        NaN          NaN                NaN
#  12141           NaN   NaN        NaN          NaN                NaN
#  12142           NaN   NaN        NaN          NaN                NaN
#  12143           NaN   NaN        NaN          NaN                NaN
#
#           clase_de_empleado profesion escolaridad  codigo_dane  cantidad
#  id
#  0      EMPLEADO PARTICULAR       NaN    PRIMARIA   91001000.0       1.0
#  1            INDEPENDIENTE       NaN  SECUNDARIA    5034000.0       1.0
#  2      EMPLEADO PARTICULAR       NaN    PRIMARIA    5001000.0       1.0
#  3      EMPLEADO PARTICULAR       NaN  SECUNDARIA    5001000.0       1.0
#  4            INDEPENDIENTE       NaN  SECUNDARIA    5001000.0       1.0
#  ...                    ...       ...         ...          ...       ...
#  12139  EMPLEADO PARTICULAR       NaN    PRIMARIA   76828000.0       1.0
#  12140                  NaN       NaN         NaN          NaN   12164.0
#  12141                  NaN       NaN         NaN          NaN       NaN
#  12142                  NaN       NaN         NaN          NaN       NaN
#  12143                  NaN       NaN         NaN          NaN       NaN
#
#  [12144 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2017-01-01 00:00:00     AMAZONAS
#  1                                    2017-01-01 00:00:00    ANTIOQUIA
#  2                                    2017-01-01 00:00:00    ANTIOQUIA
#  3                                    2017-01-01 00:00:00    ANTIOQUIA
#  4                                    2017-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12058                                2017-12-31 00:00:00      VICHADA
#  12059                                              TOTAL          NaN
#  12060  FUENTE:   DIJIN-POLICÍA NACIONAL. DATOS EXTRAI...          NaN
#  12061        Elaboró: PT Javier Andrés Lozano Rodríguez.          NaN
#  12062                Revisó: SI. Osmar Alexis Rojas Ruiz          NaN
#
#                   municipio      dia      hora        barrio    zona  \
#  id
#  0             LETICIA (CT)  Domingo  15:05:00  KILOMETRO 11   RURAL
#  1                  BETANIA  Domingo  21:20:00     LA CUMBRE  URBANA
#  2               COPACABANA  Domingo  04:48:00       MACHADO  URBANA
#  3                  EBÉJICO  Domingo  05:00:00         SAGUA   RURAL
#  4                 EL BAGRE  Domingo  06:30:00    LAS BRISAS  URBANA
#  ...                    ...      ...       ...           ...     ...
#  12058  PUERTO CARREÑO (CT)  Domingo  02:00:00      ACEITICO   RURAL
#  12059                  NaN      NaN       NaN           NaN     NaN
#  12060                  NaN      NaN       NaN           NaN     NaN
#  12061                  NaN      NaN       NaN           NaN     NaN
#  12062                  NaN      NaN       NaN           NaN     NaN
#
#                clase_de_sitio                arma_empleada  \
#  id
#  0                  CARRETERA  ARMA BLANCA / CORTOPUNZANTE
#  1              VIAS PUBLICAS                ARMA DE FUEGO
#  2      DENTRO DE LA VIVIENDA  ARMA BLANCA / CORTOPUNZANTE
#  3         FINCAS Y SIMILARES                ARMA DE FUEGO
#  4              VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#  ...                      ...                          ...
#  12058                   ISLA  ARMA BLANCA / CORTOPUNZANTE
#  12059                    NaN                          NaN
#  12060                    NaN                          NaN
#  12061                    NaN                          NaN
#  12062                    NaN                          NaN
#
#                movil_agresor         movil_victima edad       sexo  \
#  id
#  0      PASAJERO MOTOCICLETA  PASAJERO MOTOCICLETA   20  MASCULINO
#  1                     A PIE                 A PIE   21  MASCULINO
#  2                     A PIE                 A PIE   22  MASCULINO
#  3                     A PIE                 A PIE   46  MASCULINO
#  4                     A PIE                 A PIE   37  MASCULINO
#  ...                     ...                   ...  ...        ...
#  12058                 A PIE                 A PIE   54   FEMENINO
#  12059                   NaN                   NaN  NaN        NaN
#  12060                   NaN                   NaN  NaN        NaN
#  12061                   NaN                   NaN  NaN        NaN
#  12062                   NaN                   NaN  NaN        NaN
#
#        estado_civil pais_de_nacimiento    clase_de_empleado profesion  \
#  id
#  0          SOLTERO           COLOMBIA  EMPLEADO PARTICULAR       NaN
#  1          SOLTERO           COLOMBIA        INDEPENDIENTE       NaN
#  2      UNION LIBRE           COLOMBIA        INDEPENDIENTE       NaN
#  3          SOLTERO           COLOMBIA        INDEPENDIENTE       NaN
#  4      UNION LIBRE           COLOMBIA        INDEPENDIENTE       NaN
#  ...            ...                ...                  ...       ...
#  12058      SOLTERO           COLOMBIA        INDEPENDIENTE       NaN
#  12059          NaN                NaN                  NaN       NaN
#  12060          NaN                NaN                  NaN       NaN
#  12061          NaN                NaN                  NaN       NaN
#  12062          NaN                NaN                  NaN       NaN
#
#        escolaridad  codigo_dane  cantidad
#  id
#  0      SECUNDARIA   91001000.0       1.0
#  1        PRIMARIA    5091000.0       1.0
#  2      SECUNDARIA    5212000.0       1.0
#  3      SECUNDARIA    5240000.0       1.0
#  4        PRIMARIA    5250000.0       1.0
#  ...           ...          ...       ...
#  12058    PRIMARIA   99001000.0       1.0
#  12059         NaN          NaN   12077.0
#  12060         NaN          NaN       NaN
#  12061         NaN          NaN       NaN
#  12062         NaN          NaN       NaN
#
#  [12063 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2018-01-01 00:00:00     AMAZONAS
#  1                                    2018-01-01 00:00:00     AMAZONAS
#  2                                    2018-01-01 00:00:00    ANTIOQUIA
#  3                                    2018-01-01 00:00:00    ANTIOQUIA
#  4                                    2018-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12645                                2018-12-31 00:00:00        VALLE
#  12646                                                NaN          NaN
#  12647  FUENTE:   DIJIN-POLICÍA NACIONAL. DATOS EXTRAI...          NaN
#  12648                  Elaboró: PT Andres Felipe Taborda          NaN
#  12649          Revisó: IT. John Alexander Ruíz Rodríguez          NaN
#
#            municipio    dia      hora            barrio    zona  \
#  id
#  0      LETICIA (CT)  Lunes  09:45:00         ESPERANZA  URBANA
#  1      LETICIA (CT)  Lunes  09:45:00         ESPERANZA  URBANA
#  2             ANDES  Lunes  08:30:00   ALTO DEL CEDRON   RURAL
#  3             ANDES  Lunes  02:30:00  PARQUE PRINCIPAL   RURAL
#  4             ANORÍ  Lunes  03:30:00            TENCHE   RURAL
#  ...             ...    ...       ...               ...     ...
#  12645         TULUÁ  Lunes  03:10:00      La Esperanza  URBANA
#  12646           NaN    NaN       NaN               NaN     NaN
#  12647           NaN    NaN       NaN               NaN     NaN
#  12648           NaN    NaN       NaN               NaN     NaN
#  12649           NaN    NaN       NaN               NaN     NaN
#
#                      clase_de_sitio                arma_empleada movil_agresor  \
#  id
#  0                    VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  1                    VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  2                    VIAS PUBLICAS                ARMA DE FUEGO         A PIE
#  3                          PARQUES  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  4      BARES, CANTINAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  ...                            ...                          ...           ...
#  12645                VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE         A PIE
#  12646                          NaN                          NaN           NaN
#  12647                          NaN                          NaN           NaN
#  12648                          NaN                          NaN           NaN
#  12649                          NaN                          NaN           NaN
#
#        movil_victima edad       sexo estado_civil pais_de_nacimiento  \
#  id
#  0             A PIE   16  MASCULINO      SOLTERO             BRASIL
#  1             A PIE   17  MASCULINO      SOLTERO             BRASIL
#  2             A PIE   26  MASCULINO      SOLTERO           COLOMBIA
#  3             A PIE   30  MASCULINO      SOLTERO           COLOMBIA
#  4             A PIE   25  MASCULINO  UNION LIBRE           COLOMBIA
#  ...             ...  ...        ...          ...                ...
#  12645         A PIE   16  MASCULINO      SOLTERO           COLOMBIA
#  12646           NaN  NaN        NaN          NaN                NaN
#  12647           NaN  NaN        NaN          NaN                NaN
#  12648           NaN  NaN        NaN          NaN                NaN
#  12649           NaN  NaN        NaN          NaN                NaN
#
#           clase_de_empleado profesion escolaridad  codigo_dane  cantidad
#  id
#  0      EMPLEADO PARTICULAR       NaN  SECUNDARIA   91001000.0       1.0
#  1      EMPLEADO PARTICULAR       NaN  SECUNDARIA   91001000.0       1.0
#  2            INDEPENDIENTE       NaN    PRIMARIA    5034000.0       1.0
#  3               AGRICULTOR       NaN    PRIMARIA    5034000.0       1.0
#  4            INDEPENDIENTE       NaN    PRIMARIA    5040000.0       1.0
#  ...                    ...       ...         ...          ...       ...
#  12645           ESTUDIANTE       NaN  SECUNDARIA   76834000.0       1.0
#  12646                  NaN       NaN         NaN          NaN   12667.0
#  12647                  NaN       NaN         NaN          NaN       NaN
#  12648                  NaN       NaN         NaN          NaN       NaN
#  12649                  NaN       NaN         NaN          NaN       NaN
#
#  [12650 rows x 20 columns],
#                                                     fecha departamento  \
#  id
#  0                                    2019-01-01 00:00:00    ANTIOQUIA
#  1                                    2019-01-01 00:00:00    ANTIOQUIA
#  2                                    2019-01-01 00:00:00    ANTIOQUIA
#  3                                    2019-01-01 00:00:00    ANTIOQUIA
#  4                                    2019-01-01 00:00:00    ANTIOQUIA
#  ...                                                  ...          ...
#  12512                                2019-12-31 00:00:00        VALLE
#  12513                                                NaN          NaN
#  12514  FUENTE:                     DIJIN-POLICÍA NACI...          NaN
#  12515                Elaboró: PT. Andrés Felipe Taborda           NaN
#  12516               Revisó: ST. Jhon Albarracin Urrutia           NaN
#
#         municipio     dia      hora             barrio    zona  \
#  id
#  0        ARGELIA  Martes  03:00:00          SAN PABLO   RURAL
#  1          BELLO  Martes  04:49:00         PLAYA RICA  URBANA
#  2          BELLO  Martes  18:43:00       LA MILAGROSA  URBANA
#  3        BRICEÑO  Martes  21:40:00  SECTOR CEMENTERIO  URBANA
#  4      CONCORDIA  Martes  22:05:00            PEÑITAS  URBANA
#  ...          ...     ...       ...                ...     ...
#  12512      TULUÁ  Martes  23:50:00      Villa Liliana  URBANA
#  12513        NaN     NaN       NaN                NaN     NaN
#  12514        NaN     NaN       NaN                NaN     NaN
#  12515        NaN     NaN       NaN                NaN     NaN
#  12516        NaN     NaN       NaN                NaN     NaN
#
#                             clase_de_sitio                arma_empleada  \
#  id
#  0                      FINCAS Y SIMILARES  ARMA BLANCA / CORTOPUNZANTE
#  1      FRENTE A RESIDENCIAS - VIA PUBLICA                ARMA DE FUEGO
#  2                     CASAS DE HABITACION  ARMA BLANCA / CORTOPUNZANTE
#  3                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#  4                           VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#  ...                                   ...                          ...
#  12512                       VIAS PUBLICAS                ARMA DE FUEGO
#  12513                                 NaN                          NaN
#  12514                                 NaN                          NaN
#  12515                                 NaN                          NaN
#  12516                                 NaN                          NaN
#
#                movil_agresor movil_victima  edad       sexo estado_civil  \
#  id
#  0                     A PIE         A PIE  37.0  MASCULINO  UNION LIBRE
#  1      PASAJERO MOTOCICLETA         A PIE  24.0  MASCULINO      SOLTERO
#  2                     A PIE         A PIE  62.0   FEMENINO     SEPARADO
#  3                     A PIE         A PIE  34.0  MASCULINO      SOLTERO
#  4                     A PIE         A PIE  33.0  MASCULINO      SOLTERO
#  ...                     ...           ...   ...        ...          ...
#  12512             BICICLETA         A PIE  19.0  MASCULINO  UNION LIBRE
#  12513                   NaN           NaN   NaN        NaN          NaN
#  12514                   NaN           NaN   NaN        NaN          NaN
#  12515                   NaN           NaN   NaN        NaN          NaN
#  12516                   NaN           NaN   NaN        NaN          NaN
#
#        pais_de_nacimiento    clase_de_empleado                    profesion  \
#  id
#  0               COLOMBIA        INDEPENDIENTE                          NaN
#  1               COLOMBIA        INDEPENDIENTE                          NaN
#  2               COLOMBIA          AMA DE CASA  ADMINISTRACION  DE EMPRESAS
#  3               COLOMBIA    EMPLEADO EJERCITO                          NaN
#  4               COLOMBIA        INDEPENDIENTE                          NaN
#  ...                  ...                  ...                          ...
#  12512           COLOMBIA  EMPLEADO PARTICULAR                          NaN
#  12513                NaN                  NaN                          NaN
#  12514                NaN                  NaN                          NaN
#  12515                NaN                  NaN                          NaN
#  12516                NaN                  NaN                          NaN
#
#        escolaridad  codigo_dane  cantidad
#  id
#  0      ANALFABETA    5055000.0       1.0
#  1      SECUNDARIA    5088000.0       1.0
#  2        SUPERIOR    5088000.0       1.0
#  3      SECUNDARIA    5107000.0       1.0
#  4      SECUNDARIA    5209000.0       1.0
#  ...           ...          ...       ...
#  12512  SECUNDARIA   76834000.0       1.0
#  12513         NaN          NaN   12558.0
#  12514         NaN          NaN       NaN
#  12515         NaN          NaN       NaN
#  12516         NaN          NaN       NaN
#
#  [12517 rows x 20 columns]]

# %%
renaming={
    'clase_sitio':'clase_de_sitio',
    'pais_nace':'pais_de_nacimiento',
    'clase_empleado':'clase_de_empleado'
}

for i in range(len(all_dfs)):
    all_dfs[i].rename(columns=renaming, inplace=True)
    
df_f = pd.concat(all_dfs, axis=0)

# %%
df_f # also try: .describe

# %%
df_f.isnull().sum()

# %%
df_f.drop(columns=['2010','2011','2012','profesion'], inplace=True)

# %%
df_f

# %%
df_f = df_f.reset_index()

# %%
df_f

# %%
df_f.drop(columns=['id'], inplace=True)

# %%
df_f

# %%
df_f = df_f[df_f.isnull().sum(axis=1) < 5]

# %%
df_f

# %%
df_f.isnull().sum()

# %%
df_f.hora = pd.to_datetime(df_f.hora, format='%H:%M:%S')
df_f.fecha = pd.to_datetime(df_f.fecha, format = '%Y- %m - %d %H:%M:%S')
df_f['year'] = df_f.fecha.dt.year
df_f['hora_int'] = df_f.hora.dt.hour

# %%
df_f.edad.replace('NO REPORTADO', np.nan, inplace=True)

# %%
df_f.edad = df_f.edad.astype(float)

# %%
df_f.municipio.replace(' \(CT\)', '', regex=True, inplace=True)
df_f.municipio.replace('BOGOTÁ', 'BOGOTA D.C', inplace=True)
df_f.departamento.replace('BOGOTÁ', 'BOGOTA D.C', inplace=True)
df_f.departamento.replace('GUAJIRA', 'LA GUAJIRA', inplace=True)
df_f.departamento.replace('VALLE', 'VALLE DEL CAUCA', inplace=True)
df_f.departamento.replace('NARIÑO', 'NARINO', inplace=True)

# %%
for col in df_f.columns:
    print(col)
    print(df_f[col].unique())

# %% [markdown]
# # EDA

# %%
df_f.columns

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 14
# mpl.rcParams.keys()
sns.set_palette('Accent')

# %%
plt.figure(figsize=(16,9))
ax = sns.lineplot(
                    data=df_f.groupby('fecha').apply(lambda df: df.sexo.value_counts()).reset_index(),
                    x='fecha',
                    y='sexo',
                    hue='level_1'
                 )
 
ax.set_title('Time Series Total Cases Per Day');
ax.legend(['Male', 'Female', 'Not Found']);

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,9))
ax = sns.countplot(# count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.
                   data = df_f,
                   x='year',
                   hue='sexo'
                  )

ax.set_title('Counts per Year');
ax.legend(['Mascullino', 'Femenino']);

plt.savefig('figura1.png')

# %%
plt.figure(figsize=(16,9))
ax = sns.countplot(
                    data=df_f,
                    x='departamento'
)

plt.xticks(rotation=45,ha='right');

# %%
plt.figure(figsize=(16,9))

order = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
ax = sns.countplot(
                   data=df_f,
                   x='dia',
                   order=order
                  )

# %%
plt.figure(figsize=(16,9))
ax = sns.countplot(
    data=df_f,
    x='zona',
)

# %%
plt.figure(figsize=(16,9))

sns.barplot(
    data=df_f.clase_de_sitio.value_counts().head(10).to_frame(name='count').reset_index(),
    x='index',
    y='count'
) 

plt.xticks(rotation=45, ha='right');

# %%
plt.figure(figsize=(16,9))

sns.countplot(
    data=df_f,
    x='escolaridad',
);

# %%
plt.figure(figsize=(16,9))

sns.countplot(
    data=df_f,
    x='arma_empleada',
);
plt.xticks(rotation=45, ha='right');

# %%
plt.figure(figsize=(16,9))

sns.barplot(
    data=df_f.profesiones.value_counts().to_frame('count').reset_index().head(10),
    x='index',
    y='count'
) 

plt.xticks(rotation=45, ha='right');

# %%
df_f['hora']

# %%
plt.figure(figsize=(16,9))
sns.countplot(
              df_f.hora_int
             );

plt.savefig('figura_2.png')

# %%
plt.figure(figsize=(16,9))

sns.distplot(
    df_f.edad
);

# %%
sns.set_palette('Set1')
fig, ax = plt.subplots(figsize=(16,9))
sns.violinplot(
    data=df_f[df_f.sexo != "NO REPORTA"],
    x='year',
    y='hora_int',
    hue='sexo',
    ax=ax,
    split=True,
    palette="Accent"
);

# %%
fig, ax = plt.subplots(5, 1, figsize=(16,20), sharex=True)
i=0
for year in np.arange(2015,2020):
    sns.distplot(
        df_f.loc[((df_f.sexo == 'MASCULINO') & (df_f.year == year)), 'hora_int'],
        bins=20,
        color='limegreen',
        label='Male',
        ax=ax[i]
    )

    sns.distplot(
        df_f.loc[((df_f.sexo == 'FEMENINO') & (df_f.year == year)), 'hora_int'],
        bins=20,
        color='orchid',
        label='Female',
        ax=ax[i]
    )
    ax[i].set_title(str(year))
    ax[i].set_xlabel('')
    i+=1

ax[0].legend()
ax[-1].set_xlabel('Hora Del Incidente');

# %% [markdown]
# ## Maps of counts

# %%
import json

with open('./data/geojson_departamentos.json', 'r') as f:
    departamentos = json.load(f)
    
areas = pd.read_json('./data/areas_departamentos.json',
                     orient='index')
# with open('./data/geoJson_departamentos.json', 'w') as f:
#     json.dump(departamentos, f)

# with open('./data/areas_departamentos.json', 'w') as f:
#     json.dump(areas, f)

# %%
import plotly.express as px

# %%
df_f.departamento = df_f.departamento.apply(unidecode)

# %%
count_2019 = df_f[df_f.year == 2019].departamento.value_counts().reset_index(name='count')
fig = px.choropleth_mapbox(
    count_2019,
    geojson=departamentos,
    locations='index',
    color='count',
    color_continuous_scale="Viridis",
    mapbox_style="carto-positron",
    zoom=4,
    center = {"lat": 3.47, "lon": -73.96},
    opacity=0.5
)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
